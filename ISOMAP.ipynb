# %%
from sklearn.manifold import Isomap
from utils import get_dataset, make_plot
from metrics import knn_accuracy, stability, stress, strain

# %%
input, labels = get_dataset("mnist", 0.02)

embedder = Isomap(n_neighbors=10)
embeddings = embedder.fit_transform(input)
# Out:
# (70000, 784)
# (70000,)

# %%
make_plot(embeddings, labels, marker_size=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## EVALUATE METRICS

# %%
knn_accuracy(embeddings,labels)
# Out:
# (0.5539285714285714, 0.025073870454954437)

# %%
input1, labels1 = get_dataset("coil20",sample_percent=0.2)
embedding1 = embedder.fit_transform(input1)

input2, labels2 = get_dataset("coil20")
embedding2 = embedder.fit_transform(input2)
embedding2 = embedding2[0:int(0.2*len(embedding2)) ]
labels2 =  labels2[0:int(0.2*len(labels2)) ]

# compute the metric
stability(embedding1, embedding2)
# Out:
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\sklearn\manifold\_isomap.py:348: UserWarning: The number of connected components of the neighbors graph is 4 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\tools\miniconda3\envs\pytorch\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# 0.7576071288324374

# %%
stress(input, embeddings)
# Out:
# 9431604971081.49

# %%
strain(input, embeddings)
# Out:
# 8.554350285161193e+19
